# %% [markdown]
# # Thyroid Cancer

# %% [markdown]
# To solve the question: "What's the relationship between the TP53 and Thyroid Cancer when considering the influence of age?"

# %%
import pandas as pd

# Load clinical data
clinical_data = pd.read_csv(r'C:\Users\张宇强\Desktop\TCGA.THCA.sampleMap_THCA_clinicalMatrix', sep='\t', index_col=0)

# Load gene expression data
gene_data = pd.read_csv(r'C:\Users\张宇强\Desktop\HiSeqV2_PANCAN', sep='\t', index_col=0)

# %%
clinical_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                     _cohort  \
# sampleID
# TCGA-4C-A93U-01  TCGA-4C-A93U-01  TCGA-4C-A93U  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0YZ-01  TCGA-BJ-A0YZ-01  TCGA-BJ-A0YZ  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z0-01  TCGA-BJ-A0Z0-01  TCGA-BJ-A0Z0  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z2  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z3  TCGA Thyroid Cancer (THCA)
#
#                   _primary_disease  _primary_site  \
# sampleID
# TCGA-4C-A93U-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0YZ-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z0-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z2-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z3-01  thyroid carcinoma  Thyroid Gland
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-4C-A93U-01                               NaN
# TCGA-BJ-A0YZ-01                               NaN
# TCGA-BJ-A0Z0-01                               NaN
# TCGA-BJ-A0Z2-01                               YES
# TCGA-BJ-A0Z3-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-4C-A93U-01                          NaN
# TCGA-BJ-A0YZ-01                          NaN
# TCGA-BJ-A0Z0-01                          NaN
# TCGA-BJ-A0Z2-01                          NaN
# TCGA-BJ-A0Z3-01                          NaN
#
#                 additional_surgery_locoregional_procedure  \
# sampleID
# TCGA-4C-A93U-01                                       NaN
# TCGA-BJ-A0YZ-01                                       NaN
# TCGA-BJ-A0Z0-01                                       NaN
# TCGA-BJ-A0Z2-01                                       YES
# TCGA-BJ-A0Z3-01                                       NaN
#
#                  age_at_initial_pathologic_diagnosis bcr_followup_barcode  \
# sampleID
# TCGA-4C-A93U-01                                   74  TCGA-4C-A93U-F67923
# TCGA-BJ-A0YZ-01                                   65  TCGA-BJ-A0YZ-F19417
# TCGA-BJ-A0Z0-01                                   55  TCGA-BJ-A0Z0-F19426
# TCGA-BJ-A0Z2-01                                   57  TCGA-BJ-A0Z2-F71986
# TCGA-BJ-A0Z3-01                                   33  TCGA-BJ-A0Z3-F19458
#
#                  ... _GENOMIC_ID_TCGA_THCA_PDMRNAseqCNV  \
# sampleID         ...
# TCGA-4C-A93U-01  ...                    TCGA-4C-A93U-01
# TCGA-BJ-A0YZ-01  ...                    TCGA-BJ-A0YZ-01
# TCGA-BJ-A0Z0-01  ...                    TCGA-BJ-A0Z0-01
# TCGA-BJ-A0Z2-01  ...                    TCGA-BJ-A0Z2-01
# TCGA-BJ-A0Z3-01  ...                    TCGA-BJ-A0Z3-01
#
#                 _GENOMIC_ID_TCGA_THCA_mutation_bcgsc_gene  \
# sampleID
# TCGA-4C-A93U-01              TCGA-4C-A93U-01A-11D-A397-08
# TCGA-BJ-A0YZ-01              TCGA-BJ-A0YZ-01A-11D-A10S-08
# TCGA-BJ-A0Z0-01              TCGA-BJ-A0Z0-01A-11D-A10S-08
# TCGA-BJ-A0Z2-01              TCGA-BJ-A0Z2-01A-11D-A10S-08
# TCGA-BJ-A0Z3-01              TCGA-BJ-A0Z3-01A-11D-A13W-08
#
#                 _GENOMIC_ID_TCGA_THCA_mutation  \
# sampleID
# TCGA-4C-A93U-01                            NaN
# TCGA-BJ-A0YZ-01   TCGA-BJ-A0YZ-01A-11D-A10S-08
# TCGA-BJ-A0Z0-01   TCGA-BJ-A0Z0-01A-11D-A10S-08
# TCGA-BJ-A0Z2-01   TCGA-BJ-A0Z2-01A-11D-A10S-08
# TCGA-BJ-A0Z3-01   TCGA-BJ-A0Z3-01A-11D-A13W-08
#
#                  _GENOMIC_ID_TCGA_THCA_PDMRNAseq  \
# sampleID
# TCGA-4C-A93U-01                  TCGA-4C-A93U-01
# TCGA-BJ-A0YZ-01                  TCGA-BJ-A0YZ-01
# TCGA-BJ-A0Z0-01                  TCGA-BJ-A0Z0-01
# TCGA-BJ-A0Z2-01                  TCGA-BJ-A0Z2-01
# TCGA-BJ-A0Z3-01                  TCGA-BJ-A0Z3-01
#
#                  _GENOMIC_ID_TCGA_THCA_mutation_broad_gene  \
# sampleID
# TCGA-4C-A93U-01               TCGA-4C-A93U-01A-11D-A397-08
# TCGA-BJ-A0YZ-01               TCGA-BJ-A0YZ-01A-11D-A10S-08
# TCGA-BJ-A0Z0-01               TCGA-BJ-A0Z0-01A-11D-A10S-08
# TCGA-BJ-A0Z2-01               TCGA-BJ-A0Z2-01A-11D-A10S-08
# TCGA-BJ-A0Z3-01               TCGA-BJ-A0Z3-01A-11D-A13W-08
#
#                  _GENOMIC_ID_TCGA_THCA_exp_HiSeqV2_exon  \
# sampleID
# TCGA-4C-A93U-01    faddc64d-e125-4a53-a37c-b4e615ae9df9
# TCGA-BJ-A0YZ-01    1ba7877e-fd4e-452d-8eed-20fc9fb39698
# TCGA-BJ-A0Z0-01    27532782-f61f-466c-9758-d693eeecc86f
# TCGA-BJ-A0Z2-01    b854167d-42a2-4144-92ee-0229536d4cea
# TCGA-BJ-A0Z3-01    000b3ce1-5bcf-4dd5-b7e4-e4f9367a939b
#
#                  _GENOMIC_ID_TCGA_THCA_miRNA_HiSeq  \
# sampleID
# TCGA-4C-A93U-01                    TCGA-4C-A93U-01
# TCGA-BJ-A0YZ-01                    TCGA-BJ-A0YZ-01
# TCGA-BJ-A0Z0-01                    TCGA-BJ-A0Z0-01
# TCGA-BJ-A0Z2-01                    TCGA-BJ-A0Z2-01
# TCGA-BJ-A0Z3-01                    TCGA-BJ-A0Z3-01
#
#                  _GENOMIC_ID_TCGA_THCA_exp_HiSeqV2_PANCAN  \
# sampleID
# TCGA-4C-A93U-01      faddc64d-e125-4a53-a37c-b4e615ae9df9
# TCGA-BJ-A0YZ-01      1ba7877e-fd4e-452d-8eed-20fc9fb39698
# TCGA-BJ-A0Z0-01      27532782-f61f-466c-9758-d693eeecc86f
# TCGA-BJ-A0Z2-01      b854167d-42a2-4144-92ee-0229536d4cea
# TCGA-BJ-A0Z3-01      000b3ce1-5bcf-4dd5-b7e4-e4f9367a939b
#
#                  _GENOMIC_ID_data/public/TCGA/THCA/miRNA_HiSeq_gene  \
# sampleID
# TCGA-4C-A93U-01                                    TCGA-4C-A93U-01
# TCGA-BJ-A0YZ-01                                    TCGA-BJ-A0YZ-01
# TCGA-BJ-A0Z0-01                                    TCGA-BJ-A0Z0-01
# TCGA-BJ-A0Z2-01                                    TCGA-BJ-A0Z2-01
# TCGA-BJ-A0Z3-01                                    TCGA-BJ-A0Z3-01
#
#                  _GENOMIC_ID_TCGA_THCA_gistic2thd
# sampleID
# TCGA-4C-A93U-01      TCGA-4C-A93U-01A-11D-A396-01
# TCGA-BJ-A0YZ-01      TCGA-BJ-A0YZ-01A-11D-A10T-01
# TCGA-BJ-A0Z0-01      TCGA-BJ-A0Z0-01A-11D-A10T-01
# TCGA-BJ-A0Z2-01      TCGA-BJ-A0Z2-01A-11D-A10T-01
# TCGA-BJ-A0Z3-01      TCGA-BJ-A0Z3-01A-11D-A13V-01
#
# [5 rows x 113 columns]

# %%
gene_data.head()
# Out:
#            TCGA-DJ-A4V5-01  TCGA-L6-A4EQ-01  TCGA-FE-A3PB-01  TCGA-E8-A2EA-01  \
# sample
# ARHGEF10L        -0.307792        -0.074492         0.212008        -0.149292
# HIF3A            -0.645226        -1.788826        -0.060426        -0.566526
# RNF17            -0.531035        -0.531035        -0.118135        -0.024035
# RNF10             0.026628         0.115828        -0.000672        -0.023372
# RNF11             0.486622         0.320022         0.511022         0.376622
#
#            TCGA-ET-A3DS-01  TCGA-EL-A3T8-11  TCGA-E8-A432-01  TCGA-ET-A39M-01  \
# sample
# ARHGEF10L         0.602408         0.826208        -0.770792        -0.460892
# HIF3A            -0.741326         0.374774        -0.467626        -0.726526
# RNF17            -0.531035         0.497265        -0.531035        -0.531035
# RNF10             0.377528        -0.035172        -0.097372         0.101028
# RNF11             0.948622         0.540922        -0.012078         0.194022
#
#            TCGA-EL-A3T8-01  TCGA-ET-A25K-01  ...  TCGA-DJ-A2Q4-01  \
# sample                                       ...
# ARHGEF10L        -0.750892        -1.080692  ...        -0.167092
# HIF3A            -1.548626        -1.129626  ...        -2.559326
# RNF17            -0.079535        -0.531035  ...        -0.210135
# RNF10             0.037528         0.001128  ...         0.106628
# RNF11             0.542722         0.805722  ...         0.610322
#
#            TCGA-CE-A485-01  TCGA-J8-A3YH-06  TCGA-DJ-A2PN-01  TCGA-IM-A4EB-01  \
# sample
# ARHGEF10L        -0.135192        -0.163792         0.130108         0.157108
# HIF3A            -0.227026        -1.031526        -1.670726        -0.873726
# RNF17            -0.531035        -0.531035        -0.531035         0.003265
# RNF10            -0.155872        -0.036472        -0.140972         0.130828
# RNF11             0.554422         0.479622         0.800422         0.481122
#
#            TCGA-EM-A3O9-01  TCGA-ET-A25O-01  TCGA-KS-A41L-01  TCGA-J8-A3NZ-01  \
# sample
# ARHGEF10L         1.020108         0.019708         3.009808         0.131808
# HIF3A             1.206974        -3.182926        -0.439126        -1.694726
# RNF17            -0.531035        -0.531035        -0.024235         0.792265
# RNF10             0.953028         0.032028         0.676728        -0.251672
# RNF11             0.728022         0.935522         0.685322         0.960622
#
#            TCGA-DJ-A1QG-01
# sample
# ARHGEF10L        -0.451292
# HIF3A             0.732174
# RNF17            -0.531035
# RNF10             0.327628
# RNF11             0.930122
#
# [5 rows x 572 columns]

# %%
gene_fullname = 'TR53'
gene = 'TR53 GENE'
condition = 'age'
condition_col = 'days_to_birth'
trait = 'Sarcoma'

# Get the feature dimension of clinical data, and the number of genes
col_offset = len(clinical_data.columns)
num_genes = len(gene_data)
print(f'The clinical dataset has {col_offset} features, and the gene dataset includes {num_genes} genes')
gene_data.T
# Out:
# The clinical dataset has 113 features, and the gene dataset includes 20530 genes
# sample           ARHGEF10L     HIF3A     RNF17     RNF10     RNF11    RNF13  \
# TCGA-DJ-A4V5-01  -0.307792 -0.645226 -0.531035  0.026628  0.486622 -0.13431
# TCGA-L6-A4EQ-01  -0.074492 -1.788826 -0.531035  0.115828  0.320022  0.12289
# TCGA-FE-A3PB-01   0.212008 -0.060426 -0.118135 -0.000672  0.511022  0.13909
# TCGA-E8-A2EA-01  -0.149292 -0.566526 -0.024035 -0.023372  0.376622  0.00899
# TCGA-ET-A3DS-01   0.602408 -0.741326 -0.531035  0.377528  0.948622  0.93539
# ...                    ...       ...       ...       ...       ...      ...
# TCGA-EM-A3O9-01   1.020108  1.206974 -0.531035  0.953028  0.728022  0.05379
# TCGA-ET-A25O-01   0.019708 -3.182926 -0.531035  0.032028  0.935522  0.54719
# TCGA-KS-A41L-01   3.009808 -0.439126 -0.024235  0.676728  0.685322 -0.09531
# TCGA-J8-A3NZ-01   0.131808 -1.694726  0.792265 -0.251672  0.960622  0.43049
# TCGA-DJ-A1QG-01  -0.451292  0.732174 -0.531035  0.327628  0.930122  0.50989
#
# sample            GTF2IP1      REM1     MTVR2   RTN4RL2  ...     TULP2  \
# TCGA-DJ-A4V5-01  0.433406  1.657254 -0.423399  4.035928  ... -0.306678
# TCGA-L6-A4EQ-01  0.369306 -0.642146 -0.423399  2.050028  ...  0.153522
# TCGA-FE-A3PB-01  0.105506  0.899154 -0.423399  1.483128  ...  0.246922
# TCGA-E8-A2EA-01  0.319106  0.871154 -0.423399  1.722828  ... -0.241878
# TCGA-ET-A3DS-01  0.312406  0.962454 -0.423399  2.810328  ... -0.748878
# ...                   ...       ...       ...       ...  ...       ...
# TCGA-EM-A3O9-01  0.182206  1.923954 -0.423399 -0.499972  ... -0.748878
# TCGA-ET-A25O-01 -0.142294 -0.382946 -0.046799 -1.236172  ... -0.748878
# TCGA-KS-A41L-01  1.087106  2.212454 -0.423399  1.468628  ... -0.748878
# TCGA-J8-A3NZ-01  0.444006 -0.495046 -0.423399  1.285828  ... -0.748878
# TCGA-DJ-A1QG-01  0.092206  1.467554  0.337401 -0.120772  ...  0.011922
#
# sample              NPY5R     GNGT2    GNGT1     TULP3      PTRF     BCL6B  \
# TCGA-DJ-A4V5-01  0.224683  1.173267 -1.28139  0.118223  1.389414  0.980673
# TCGA-L6-A4EQ-01 -1.066517 -1.650033 -1.28139  0.052423  1.486214  0.695673
# TCGA-FE-A3PB-01 -0.591317  1.965567 -1.28139 -0.135977  1.261214  1.101873
# TCGA-E8-A2EA-01 -0.408717  1.887667 -1.28139  0.223923  1.265814  0.699873
# TCGA-ET-A3DS-01 -0.273317 -0.156633 -1.28139 -0.113277  0.330914  1.320673
# ...                   ...       ...      ...       ...       ...       ...
# TCGA-EM-A3O9-01  0.182883  0.582867  1.48101 -1.375777  0.045614  2.382273
# TCGA-ET-A25O-01 -0.665117 -1.945533 -1.28139  0.388323  1.402114 -0.716727
# TCGA-KS-A41L-01  5.061483  1.063067  1.31571  0.415423  0.614014  1.838873
# TCGA-J8-A3NZ-01 -1.208017  0.171367 -1.28139 -0.067877  1.372714  0.034973
# TCGA-DJ-A1QG-01 -1.587117  0.372267 -0.52059 -0.683477  0.152714  1.325473
#
# sample              GSTK1      SELP      SELS
# TCGA-DJ-A4V5-01  0.001105  3.612567 -0.316012
# TCGA-L6-A4EQ-01 -0.133995  1.355967 -0.419312
# TCGA-FE-A3PB-01  0.086005  2.467967  0.209188
# TCGA-E8-A2EA-01  0.717405  2.304467  0.441288
# TCGA-ET-A3DS-01  0.466205  1.110267  0.480088
# ...                   ...       ...       ...
# TCGA-EM-A3O9-01  1.985305  0.066867 -0.297112
# TCGA-ET-A25O-01 -0.777395 -1.175933 -0.548112
# TCGA-KS-A41L-01  1.905005 -2.227133  0.485288
# TCGA-J8-A3NZ-01 -0.407595  1.793167 -0.148512
# TCGA-DJ-A1QG-01  0.085005  2.164867 -0.536112
#
# [572 rows x 20530 columns]

# %%
merged_data = clinical_data.join(gene_data.T)

merged_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                     _cohort  \
# sampleID
# TCGA-4C-A93U-01  TCGA-4C-A93U-01  TCGA-4C-A93U  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0YZ-01  TCGA-BJ-A0YZ-01  TCGA-BJ-A0YZ  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z0-01  TCGA-BJ-A0Z0-01  TCGA-BJ-A0Z0  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z2-01  TCGA-BJ-A0Z2  TCGA Thyroid Cancer (THCA)
# TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z3-01  TCGA-BJ-A0Z3  TCGA Thyroid Cancer (THCA)
#
#                   _primary_disease  _primary_site  \
# sampleID
# TCGA-4C-A93U-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0YZ-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z0-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z2-01  thyroid carcinoma  Thyroid Gland
# TCGA-BJ-A0Z3-01  thyroid carcinoma  Thyroid Gland
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-4C-A93U-01                               NaN
# TCGA-BJ-A0YZ-01                               NaN
# TCGA-BJ-A0Z0-01                               NaN
# TCGA-BJ-A0Z2-01                               YES
# TCGA-BJ-A0Z3-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-4C-A93U-01                          NaN
# TCGA-BJ-A0YZ-01                          NaN
# TCGA-BJ-A0Z0-01                          NaN
# TCGA-BJ-A0Z2-01                          NaN
# TCGA-BJ-A0Z3-01                          NaN
#
#                 additional_surgery_locoregional_procedure  \
# sampleID
# TCGA-4C-A93U-01                                       NaN
# TCGA-BJ-A0YZ-01                                       NaN
# TCGA-BJ-A0Z0-01                                       NaN
# TCGA-BJ-A0Z2-01                                       YES
# TCGA-BJ-A0Z3-01                                       NaN
#
#                  age_at_initial_pathologic_diagnosis bcr_followup_barcode  \
# sampleID
# TCGA-4C-A93U-01                                   74  TCGA-4C-A93U-F67923
# TCGA-BJ-A0YZ-01                                   65  TCGA-BJ-A0YZ-F19417
# TCGA-BJ-A0Z0-01                                   55  TCGA-BJ-A0Z0-F19426
# TCGA-BJ-A0Z2-01                                   57  TCGA-BJ-A0Z2-F71986
# TCGA-BJ-A0Z3-01                                   33  TCGA-BJ-A0Z3-F19458
#
#                  ...     TULP2     NPY5R     GNGT2    GNGT1     TULP3  \
# sampleID         ...
# TCGA-4C-A93U-01  ... -0.748878 -1.018517  0.205567 -1.28139  0.395523
# TCGA-BJ-A0YZ-01  ...  0.125322  1.568883  0.626367  2.38101  0.275823
# TCGA-BJ-A0Z0-01  ... -0.748878 -0.747417 -0.931133 -1.28139 -0.222077
# TCGA-BJ-A0Z2-01  ... -0.748878 -1.587117 -1.292433 -1.28139 -0.602177
# TCGA-BJ-A0Z3-01  ... -0.413778  1.111583  1.158867 -1.28139  0.003723
#
#                      PTRF     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-4C-A93U-01  1.735414  0.945273 -0.186695  4.024767 -0.273612
# TCGA-BJ-A0YZ-01  1.820014  2.140073  1.380405  1.257367 -0.174312
# TCGA-BJ-A0Z0-01  0.293414  0.725173 -0.254095  0.530667 -0.430812
# TCGA-BJ-A0Z2-01  0.134114  0.894473 -0.380395 -2.502833  0.360588
# TCGA-BJ-A0Z3-01  1.240514  0.924373 -0.143495  2.613367 -0.030012
#
# [5 rows x 20643 columns]

# %%
input_cols = [condition_col] + merged_data.columns[col_offset: col_offset + num_genes].tolist()
merged_data = merged_data[input_cols]


threshold_rows = 0.22 * len(merged_data)
rows_after_any = len(merged_data.dropna(how='any'))

if rows_after_any >= threshold_rows:
    merged_data = merged_data.dropna(how='any')
else:
    merged_data = merged_data.dropna(how='all')
    merged_data = merged_data.fillna(0)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-4C-A93U-01         -27348  -0.767592 -1.742926 -0.531035 -0.067972
# TCGA-BJ-A0YZ-01         -24102   1.766308  0.273374 -0.531035  0.790028
# TCGA-BJ-A0Z0-01         -20361   0.986808 -2.165726 -0.050935  0.051428
# TCGA-BJ-A0Z2-01         -21008   0.767208 -1.623626 -0.531035  0.182228
# TCGA-BJ-A0Z3-01         -12295  -0.287292 -1.766626 -0.531035  0.059628
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-4C-A93U-01  0.265922 -0.13531  0.440006 -0.024246 -0.423399  ...
# TCGA-BJ-A0YZ-01  1.209322  0.01229  0.704606  2.321754 -0.423399  ...
# TCGA-BJ-A0Z0-01  0.979522  0.48229  0.090106  0.191954 -0.423399  ...
# TCGA-BJ-A0Z2-01  0.541622  0.65889  0.647206 -2.507546  0.137401  ...
# TCGA-BJ-A0Z3-01  0.920522  0.21849  0.336106  1.909954 -0.423399  ...
#
#                     TULP2     NPY5R     GNGT2    GNGT1     TULP3      PTRF  \
# sampleID
# TCGA-4C-A93U-01 -0.748878 -1.018517  0.205567 -1.28139  0.395523  1.735414
# TCGA-BJ-A0YZ-01  0.125322  1.568883  0.626367  2.38101  0.275823  1.820014
# TCGA-BJ-A0Z0-01 -0.748878 -0.747417 -0.931133 -1.28139 -0.222077  0.293414
# TCGA-BJ-A0Z2-01 -0.748878 -1.587117 -1.292433 -1.28139 -0.602177  0.134114
# TCGA-BJ-A0Z3-01 -0.413778  1.111583  1.158867 -1.28139  0.003723  1.240514
#
#                     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-4C-A93U-01  0.945273 -0.186695  4.024767 -0.273612
# TCGA-BJ-A0YZ-01  2.140073  1.380405  1.257367 -0.174312
# TCGA-BJ-A0Z0-01  0.725173 -0.254095  0.530667 -0.430812
# TCGA-BJ-A0Z2-01  0.894473 -0.380395 -2.502833  0.360588
# TCGA-BJ-A0Z3-01  0.924373 -0.143495  2.613367 -0.030012
#
# [5 rows x 20531 columns]

# %%
input_cols = merged_data.columns.tolist()
gene_list = [col for col in input_cols if gene in col.lower()]

# %%
def mark_tumor(row_index):
    last_two_digits = int(row_index[-2:])

    if 1 <= last_two_digits <= 9:
        return 1
    elif 10 <= last_two_digits <= 19:
        return 0
    else:
        return -1
merged_data[trait] = merged_data.index.to_series().apply(mark_tumor)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-4C-A93U-01         -27348  -0.767592 -1.742926 -0.531035 -0.067972
# TCGA-BJ-A0YZ-01         -24102   1.766308  0.273374 -0.531035  0.790028
# TCGA-BJ-A0Z0-01         -20361   0.986808 -2.165726 -0.050935  0.051428
# TCGA-BJ-A0Z2-01         -21008   0.767208 -1.623626 -0.531035  0.182228
# TCGA-BJ-A0Z3-01         -12295  -0.287292 -1.766626 -0.531035  0.059628
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-4C-A93U-01  0.265922 -0.13531  0.440006 -0.024246 -0.423399  ...
# TCGA-BJ-A0YZ-01  1.209322  0.01229  0.704606  2.321754 -0.423399  ...
# TCGA-BJ-A0Z0-01  0.979522  0.48229  0.090106  0.191954 -0.423399  ...
# TCGA-BJ-A0Z2-01  0.541622  0.65889  0.647206 -2.507546  0.137401  ...
# TCGA-BJ-A0Z3-01  0.920522  0.21849  0.336106  1.909954 -0.423399  ...
#
#                     NPY5R     GNGT2    GNGT1     TULP3      PTRF     BCL6B  \
# sampleID
# TCGA-4C-A93U-01 -1.018517  0.205567 -1.28139  0.395523  1.735414  0.945273
# TCGA-BJ-A0YZ-01  1.568883  0.626367  2.38101  0.275823  1.820014  2.140073
# TCGA-BJ-A0Z0-01 -0.747417 -0.931133 -1.28139 -0.222077  0.293414  0.725173
# TCGA-BJ-A0Z2-01 -1.587117 -1.292433 -1.28139 -0.602177  0.134114  0.894473
# TCGA-BJ-A0Z3-01  1.111583  1.158867 -1.28139  0.003723  1.240514  0.924373
#
#                     GSTK1      SELP      SELS  Sarcoma
# sampleID
# TCGA-4C-A93U-01 -0.186695  4.024767 -0.273612        1
# TCGA-BJ-A0YZ-01  1.380405  1.257367 -0.174312        1
# TCGA-BJ-A0Z0-01 -0.254095  0.530667 -0.430812        1
# TCGA-BJ-A0Z2-01 -0.380395 -2.502833  0.360588        1
# TCGA-BJ-A0Z3-01 -0.143495  2.613367 -0.030012        1
#
# [5 rows x 20532 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

def plot_numeric_distribution(data, column, bins=30, **kwargs):
    """
    Plots the distribution of a numeric column.

    Args:
    - data (pd.DataFrame): The dataframe containing the data.
    - column (str): The numeric column to plot.
    - bins (int): Number of bins for the histogram.
    - **kwargs: Additional keyword arguments passed to the seaborn.histplot function.
    """
    plt.figure(figsize=(10, 6))
    sns.histplot(data[column], kde=True, bins=bins, **kwargs)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {column.capitalize()}')
    plt.show()

def plot_categorical_distribution(data, column, **kwargs):
    """
    Plots the distribution of a categorical column.

    Args:
    - data (pd.DataFrame): The dataframe containing the data.
    - column (str): The categorical column to plot.
    - **kwargs: Additional keyword arguments passed to the seaborn.countplot function.
    """
    plt.figure(figsize=(10, 6))
    sns.countplot(y=column, data=data, order=data[column].value_counts().index, **kwargs)
    plt.xlabel('Frequency')
    plt.title(f'Distribution of {column.capitalize()}')
    plt.show()

def analyze_distributions(data, numerical_columns, categorical_columns):
    """
    Analyzes and plots the distributions of numeric and categorical columns in a dataframe.

    Args:
    - data (pd.DataFrame): The dataframe containing the data.
    - numerical_columns (list): List of numeric columns to analyze.
    - categorical_columns (list): List of categorical columns to analyze.
    """
    for col in numerical_columns:
        plot_numeric_distribution(data, col)
    for col in categorical_columns:
        plot_categorical_distribution(data, col)

# %% [markdown]
# As can be seen from the histogram of "Days_to_birth", the data are not within the expected range of age. This is also indicated by the variable name.

# %%
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
merged_data = merged_data.rename(columns={condition_col: condition})
input_cols = merged_data.columns.tolist()

merged_data.head()
# Out:
#                  age  ARHGEF10L     HIF3A     RNF17     RNF10     RNF11  \
# sampleID
# TCGA-4C-A93U-01   74  -0.767592 -1.742926 -0.531035 -0.067972  0.265922
# TCGA-BJ-A0YZ-01   65   1.766308  0.273374 -0.531035  0.790028  1.209322
# TCGA-BJ-A0Z0-01   55   0.986808 -2.165726 -0.050935  0.051428  0.979522
# TCGA-BJ-A0Z2-01   57   0.767208 -1.623626 -0.531035  0.182228  0.541622
# TCGA-BJ-A0Z3-01   33  -0.287292 -1.766626 -0.531035  0.059628  0.920522
#
#                    RNF13   GTF2IP1      REM1     MTVR2  ...     NPY5R  \
# sampleID                                                ...
# TCGA-4C-A93U-01 -0.13531  0.440006 -0.024246 -0.423399  ... -1.018517
# TCGA-BJ-A0YZ-01  0.01229  0.704606  2.321754 -0.423399  ...  1.568883
# TCGA-BJ-A0Z0-01  0.48229  0.090106  0.191954 -0.423399  ... -0.747417
# TCGA-BJ-A0Z2-01  0.65889  0.647206 -2.507546  0.137401  ... -1.587117
# TCGA-BJ-A0Z3-01  0.21849  0.336106  1.909954 -0.423399  ...  1.111583
#
#                     GNGT2    GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# sampleID
# TCGA-4C-A93U-01  0.205567 -1.28139  0.395523  1.735414  0.945273 -0.186695
# TCGA-BJ-A0YZ-01  0.626367  2.38101  0.275823  1.820014  2.140073  1.380405
# TCGA-BJ-A0Z0-01 -0.931133 -1.28139 -0.222077  0.293414  0.725173 -0.254095
# TCGA-BJ-A0Z2-01 -1.292433 -1.28139 -0.602177  0.134114  0.894473 -0.380395
# TCGA-BJ-A0Z3-01  1.158867 -1.28139  0.003723  1.240514  0.924373 -0.143495
#
#                      SELP      SELS  Sarcoma
# sampleID
# TCGA-4C-A93U-01  4.024767 -0.273612        1
# TCGA-BJ-A0YZ-01  1.257367 -0.174312        1
# TCGA-BJ-A0Z0-01  0.530667 -0.430812        1
# TCGA-BJ-A0Z2-01 -2.502833  0.360588        1
# TCGA-BJ-A0Z3-01  2.613367 -0.030012        1
#
# [5 rows x 20532 columns]

# %% [markdown]
# # 3. Do regression & Cross Validation

# %%
def plot_distribution(df, column, kind='numeric', **kwargs):
    """
    Plots the distribution of a column.
    
    Args:
    - df (DataFrame): The dataframe containing the data.
    - column (str): The column to plot.
    - kind (str): The type of plot ('numeric' or 'categorical').
    - **kwargs: Additional keyword arguments passed to the seaborn plotting function.
    """
    plt.figure(figsize=(10, 6))
    
    if kind == 'numeric':
        sns.histplot(df[column], kde=True, bins=30, **kwargs)
        plt.ylabel('Frequency')
    elif kind == 'categorical':
        sns.countplot(y=column, data=df, order=df[column].value_counts().index, **kwargs)
        plt.xlabel('Frequency')
        
    plt.title(f'Distribution of {column.capitalize()}')
    plt.show()

def analyze_distributions(df, numerical_columns, categorical_columns):
    for col in numerical_columns:
        plot_distribution(df, col, kind='numeric')
    for col in categorical_columns:
        plot_distribution(df, col, kind='categorical')

# Sample usage:
analyze_distributions(merged_data, numerical_columns=[condition_col, *gene_list], categorical_columns=[trait])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'days_to_birth'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\temp\temp\ipykernel_13808\2136862868.py in <module>
#      28
#      29 # Sample usage:
# ---> 30 analyze_distributions(merged_data, numerical_columns=[condition_col, *gene_list], categorical_columns=[trait])
#
# d:\temp\temp\ipykernel_13808\2136862868.py in analyze_distributions(df, numerical_columns, categorical_columns)
#      23 def analyze_distributions(df, numerical_columns, categorical_columns):
#      24     for col in numerical_columns:
# ---> 25         plot_distribution(df, col, kind='numeric')
#      26     for col in categorical_columns:
#      27         plot_distribution(df, col, kind='categorical')
#
# d:\temp\temp\ipykernel_13808\2136862868.py in plot_distribution(df, column, kind, **kwargs)
#      12
#      13     if kind == 'numeric':
# ---> 14         sns.histplot(df[column], kde=True, bins=30, **kwargs)
#      15         plt.ylabel('Frequency')
#      16     elif kind == 'categorical':
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'days_to_birth'

# %%
import numpy as np
import statsmodels.api as sm

def conduct_regression(X, y):
    """Conduct regression and return coefficients and negative log p-values."""
    X_with_intercept = sm.add_constant(X)  # Add a constant term for the intercept
    model = sm.OLS(y, X_with_intercept)
    results = model.fit()
    coefficients = results.params
    nlog_p_values = -np.log(results.pvalues)
    return coefficients, nlog_p_values

def extract_results(input_cols, coefficients, nlog_p_values, keyword):
    """Extract and return results related to a specific keyword."""
    return [(var, coef, np.exp(-nlogp)) 
            for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values) 
            if keyword in var.lower()]

def format_results(results, keyword):
    """Format results for a given keyword."""
    report = f"For {keyword}:\n"
    for variable_name, coefficient, p_value in results:
        report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"
    return report

# Example data
X = np.random.rand(100, 3)
y = 2 * X[:, 0] + 3 * X[:, 1] + 1 * X[:, 2] + np.random.normal(scale=0.1, size=100)

# Conduct regression
coefficients, nlog_p_values = conduct_regression(X, y)

# Extract and format results for a specific keyword
keyword = "x"
results = extract_results(["Intercept", "x1", "x2", "x3"], coefficients, nlog_p_values, keyword)
report = format_results(results, keyword)

# Create the regression report
regression_report = "Regression Results:\n\n"
regression_report += report

print(regression_report)
# Out:
# Regression Results:
#
# For x:
# x1: Coefficient = 2.0407769698797287, p-value = 1.1877666532311196e-78
# x2: Coefficient = 2.985826406863615, p-value = 1.4505849991779952e-94
# x3: Coefficient = 0.936619304016943, p-value = 2.6061918170685737e-45

# %% [markdown]
# # 4. Discussion

# %%
hypotheses_text = f'Hypothesis\n\n'
hypotheses_text += f'For the question "What is the relationship between {gene_fullname} and {trait} when considering the influence of {condition}?", the following hypotheses can be proposed:\n\n'
hypotheses_text += f'Null Hypothesis (H0): There is no significant association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'
hypotheses_text += f'Alternative Hypothesis (H1): There is an association between the expression of the {gene_fullname} and {trait} when considering the influence of {condition}.\n\n'

print(hypotheses_text)
# Out:
# Hypothesis
#
# For the question "What is the relationship between TR53 and Sarcoma when considering the influence of age?", the following hypotheses can be proposed:
#
# Null Hypothesis (H0): There is no significant association between the expression of the TR53 and Sarcoma when considering the influence of age.
#
# Alternative Hypothesis (H1): There is an association between the expression of the TR53 and Sarcoma when considering the influence of age.

# %%
threshold = 0.05

def interpret_coefficient(variable_name, coefficient, p_value, significance_level=0.05):
    """Interpret the coefficient and p-value of a variable."""
    interpretation = f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}"
    
    if p_value <= significance_level:
        interpretation += " (Significant)"
    else:
        interpretation += " (Not Significant)"
    
    return interpretation + "\n"

# Assuming gene_results and condition_results are lists of tuples with (variable_name, coefficient, p_value)
gene_results = [("gene1", 0.1, 0.03), ("gene2", -0.2, 0.1)]
condition_results = [("condition1", 0.15, 0.08), ("condition2", -0.18, 0.2)]

interpretations = [
    interpret_coefficient(variable_name, coefficient, p_value, threshold)
    for variable_name, coefficient, p_value in gene_results + condition_results
]

interpretation_coefficient_report = "Interpretation of Regression Coefficients:\n\n" + ''.join(interpretations)

print(interpretation_coefficient_report)
# Out:
# Interpretation of Regression Coefficients:
#
# gene1: Coefficient = 0.1, p-value = 0.03 (Significant)
# gene2: Coefficient = -0.2, p-value = 0.1 (Not Significant)
# condition1: Coefficient = 0.15, p-value = 0.08 (Not Significant)
# condition2: Coefficient = -0.18, p-value = 0.2 (Not Significant)

# %%
def confirm_hypothesis(coefficient, p_value, variable_name, trait, condition, significance_level=0.05):
    """Determine if H0 or H1 is confirmed based on coefficient and p-value."""
    if p_value < significance_level and coefficient != 0:
        return (
            f"TMPRSS2 gene is confirmed: There is an association between the expression of "
            f"the {variable_name} and {trait} when considering the influence of {condition}."
        )
    return (
        f"TMPRSS1 gene is not rejected: There is insufficient evidence to conclude a significant "
        f"association between the expression of the {variable_name} gene and {trait} "
        f"when considering the influence of {condition}."
    )

# Assuming gene_results is a list of tuples with (variable_name, coefficient, p_value)
gene_results = [("gene1", 0.1, 0.03), ("gene2", -0.2, 0.1)]
trait = "your_trait"  # Replace with the actual trait name
condition = "your_condition"  # Replace with the actual condition name
threshold = 0.05

conclusions = [
    f"Variable: {variable_name}\n"
    f"Conclusion: {confirm_hypothesis(coefficient, p_value, variable_name, trait, condition, threshold)}\n\n"
    for variable_name, coefficient, p_value in gene_results
]

hypothesis_confirmation_report = "Hypothesis Confirmation and Conclusion:\n\n" + ''.join(conclusions)

print(hypothesis_confirmation_report)
# Out:
# Hypothesis Confirmation and Conclusion:
#
# Variable: gene1
# Conclusion: TMPRSS2 gene is confirmed: There is an association between the expression of the gene1 and your_trait when considering the influence of your_condition.
#
# Variable: gene2
# Conclusion: TMPRSS1 gene is not rejected: There is insufficient evidence to conclude a significant association between the expression of the gene2 gene and your_trait when considering the influence of your_condition.
