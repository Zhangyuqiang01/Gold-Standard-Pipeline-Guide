# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import pandas as pd

file_path = r"C:\Users\张宇强\Desktop\Breast_cancer.xlsx"
df2 = pd.read_excel(file_path, index_col=0, parse_dates=True)

# %%
df2
# Out:
#                 AJCC_Stage_nature2012  \
# sampleID
# TCGA-3C-AAAU-01                   NaN
# TCGA-3C-AALI-01                   NaN
# TCGA-3C-AALJ-01                   NaN
# TCGA-3C-AALK-01                   NaN
# TCGA-4H-AAAK-01                   NaN
# ...                               ...
# TCGA-XX-A899-01                   NaN
# TCGA-XX-A899-11                   NaN
# TCGA-XX-A89A-01                   NaN
# TCGA-Z7-A8R5-01                   NaN
# TCGA-Z7-A8R6-01                   NaN
#
#                  Age_at_Initial_Pathologic_Diagnosis_nature2012  \
# sampleID
# TCGA-3C-AAAU-01                                             NaN
# TCGA-3C-AALI-01                                             NaN
# TCGA-3C-AALJ-01                                             NaN
# TCGA-3C-AALK-01                                             NaN
# TCGA-4H-AAAK-01                                             NaN
# ...                                                         ...
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df2.index, df2['AJCC_Stage_nature2012'], label='AJCC Stage', color='blue')
plt.title('Breast cancer by age')
plt.xlabel('Date')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\temp\temp\ipykernel_21044\809697095.py in <module>
#       2
#       3 plt.figure(figsize=(10, 6))
# ----> 4 plt.plot(df2.index, df2['AJCC_Stage_nature2012'], label='AJCC Stage', color='blue')
#       5 plt.title('Breast cancer by age')
#       6 plt.xlabel('Date')
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
# ...

# %%
import pandas as pd

# Specify the full path to the CSV file
file_path = 'C:/Users/张宇强/Desktop/Breast_cancer.csv'

# Read the CSV file into a DataFrame
breast_cancer = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
breast_cancer.head()
# Out:
#           sampleID AJCC_Stage_nature2012  \
# 0  TCGA-3C-AAAU-01                   NaN
# 1  TCGA-3C-AALI-01                   NaN
# 2  TCGA-3C-AALJ-01                   NaN
# 3  TCGA-3C-AALK-01                   NaN
# 4  TCGA-4H-AAAK-01                   NaN
#
#   Days_to_Date_of_Last_Contact_nature2012  Prev Close   Open   High    Low  \
# 0                                     NaN      361.20  370.0  390.0  370.0
# 1                                     NaN      381.65  380.0  392.0  375.0
# 2                                     NaN      385.55  371.5  390.0  371.5
# 3                                     NaN      383.00  384.9  384.9  374.5
# 4                                     NaN      377.50  376.0  390.0  370.0
#
#     Last   Close    VWAP
# 0  385.0  381.65  380.54
# 1  390.0  385.55  383.50
# 2  383.0  383.00  379.81
# 3  375.1  377.50  379.88
# 4  389.0  385.70  383.38

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(df2.index, df2['Age_at_Initial_Pathologic_Diagnosis_nature2012'], label='Age at Diagnosis', color='blue')
plt.title('The relation between breast cancer and age')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
plt.plot(df2.index, df2['Age_at_Initial_Pathologic_Diagnosis_nature2012'], label='Age at Diagnosis', color='green')
plt.title('Breast cancer volume over age group')
plt.xlabel('Date')
plt.legend()
plt.show()

# %%
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
merged_data = merged_data.rename(columns={condition_col: condition})
input_cols = merged_data.columns.tolist()

merged_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\temp\temp\ipykernel_21044\506443620.py in <module>
# ----> 1 merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
#       2 merged_data = merged_data.rename(columns={condition_col: condition})
#       3 input_cols = merged_data.columns.tolist()
#       4
#       5 merged_data.head()
#
# NameError: name 'merged_data' is not defined
