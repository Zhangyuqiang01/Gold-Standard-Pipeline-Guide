# %% [markdown]
# # Mesothelioma

# %% [markdown]
# To solve the question: "What's the relationship between the NF2 gene and Mesothelioma when considering the influence of age?"

# %% [markdown]
# # 1. Data Preprocessing

# %%
import pandas as pd
import numpy as np
clinical_data = pd.read_csv(r'C:\Users\张宇强\Desktop\TCGA.MESO.sampleMap_MESO_clinicalMatrix', sep='\t', index_col=0)
gene_data = pd.read_csv(r'C:\Users\张宇强\Desktop\HiSeqV2_PANCAN', sep='\t', index_col=0)

# %%
clinical_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                   _cohort  \
# sampleID
# TCGA-3H-AB3K-01  TCGA-3H-AB3K-01  TCGA-3H-AB3K  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3L-01  TCGA-3H-AB3L-01  TCGA-3H-AB3L  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3M-01  TCGA-3H-AB3M-01  TCGA-3H-AB3M  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3O-01  TCGA-3H-AB3O-01  TCGA-3H-AB3O  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3S-01  TCGA-3H-AB3S-01  TCGA-3H-AB3S  TCGA Mesothelioma (MESO)
#
#                 _primary_disease            _primary_site  \
# sampleID
# TCGA-3H-AB3K-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3L-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3M-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3O-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3S-01     mesothelioma  Lining of body cavities
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-3H-AB3K-01                               NaN
# TCGA-3H-AB3L-01                               NaN
# TCGA-3H-AB3M-01                               NaN
# TCGA-3H-AB3O-01                               NaN
# TCGA-3H-AB3S-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-3H-AB3K-01                          NaN
# TCGA-3H-AB3L-01                          NaN
# TCGA-3H-AB3M-01                          NaN
# TCGA-3H-AB3O-01                          NaN
# TCGA-3H-AB3S-01                          NaN
#
#                  age_at_initial_pathologic_diagnosis  asbestos_exposure_age  \
# sampleID
# TCGA-3H-AB3K-01                                   64                    NaN
# TCGA-3H-AB3L-01                                   60                    NaN
# TCGA-3H-AB3M-01                                   53                    NaN
# TCGA-3H-AB3O-01                                   58                   25.0
# TCGA-3H-AB3S-01                                   69                    NaN
#
#                  asbestos_exposure_age_last  ...  \
# sampleID                                     ...
# TCGA-3H-AB3K-01                         NaN  ...
# TCGA-3H-AB3L-01                         NaN  ...
# TCGA-3H-AB3M-01                         NaN  ...
# TCGA-3H-AB3O-01                        31.0  ...
# TCGA-3H-AB3S-01                         NaN  ...
#
#                 _GENOMIC_ID_TCGA_MESO_mutation_bcgsc_gene  \
# sampleID
# TCGA-3H-AB3K-01              TCGA-3H-AB3K-01A-11D-A39R-32
# TCGA-3H-AB3L-01              TCGA-3H-AB3L-01A-11D-A39R-32
# TCGA-3H-AB3M-01              TCGA-3H-AB3M-01A-11D-A39R-32
# TCGA-3H-AB3O-01              TCGA-3H-AB3O-01A-11D-A39R-32
# TCGA-3H-AB3S-01              TCGA-3H-AB3S-01A-21D-A39R-32
#
#                 _GENOMIC_ID_TCGA_MESO_exp_HiSeqV2_percentile  \
# sampleID
# TCGA-3H-AB3K-01         919d8bde-c3b7-4cd9-8463-938afdb89ad7
# TCGA-3H-AB3L-01         3baf5546-99d9-417b-97bb-e00dda7ebcdd
# TCGA-3H-AB3M-01         f0b52bcf-d7b4-4daa-82bb-e13e2d753be9
# TCGA-3H-AB3O-01         de645724-4408-4771-9814-cdeffec79758
# TCGA-3H-AB3S-01         34787f03-da7e-4f3e-b33f-73b1bf51fb74
#
#                            _GENOMIC_ID_TCGA_MESO_RPPA  \
# sampleID
# TCGA-3H-AB3K-01  FA2214BC-2F60-4767-BB8F-09679A9C0BD5
# TCGA-3H-AB3L-01  81F9016D-1F8D-4902-AA68-2002130CF41F
# TCGA-3H-AB3M-01  F98B8A5F-23ED-477D-833E-71730A4BE6B9
# TCGA-3H-AB3O-01  3B2C605A-9789-400E-B1B5-A8CEDA10E484
# TCGA-3H-AB3S-01  BF706147-4C7D-4C10-B27A-C4851B1B4DFA
#
#                 _GENOMIC_ID_TCGA_MESO_gistic2  \
# sampleID
# TCGA-3H-AB3K-01  TCGA-3H-AB3K-01A-11D-A39Q-01
# TCGA-3H-AB3L-01  TCGA-3H-AB3L-01A-11D-A39Q-01
# TCGA-3H-AB3M-01  TCGA-3H-AB3M-01A-11D-A39Q-01
# TCGA-3H-AB3O-01  TCGA-3H-AB3O-01A-11D-A39Q-01
# TCGA-3H-AB3S-01  TCGA-3H-AB3S-01A-21D-A39Q-01
#
#                 _GENOMIC_ID_TCGA_MESO_exp_HiSeqV2_PANCAN  \
# sampleID
# TCGA-3H-AB3K-01     919d8bde-c3b7-4cd9-8463-938afdb89ad7
# TCGA-3H-AB3L-01     3baf5546-99d9-417b-97bb-e00dda7ebcdd
# TCGA-3H-AB3M-01     f0b52bcf-d7b4-4daa-82bb-e13e2d753be9
# TCGA-3H-AB3O-01     de645724-4408-4771-9814-cdeffec79758
# TCGA-3H-AB3S-01     34787f03-da7e-4f3e-b33f-73b1bf51fb74
#
#                 _GENOMIC_ID_TCGA_MESO_miRNA_HiSeq  \
# sampleID
# TCGA-3H-AB3K-01                   TCGA-3H-AB3K-01
# TCGA-3H-AB3L-01                   TCGA-3H-AB3L-01
# TCGA-3H-AB3M-01                   TCGA-3H-AB3M-01
# TCGA-3H-AB3O-01                   TCGA-3H-AB3O-01
# TCGA-3H-AB3S-01                   TCGA-3H-AB3S-01
#
#                     _GENOMIC_ID_TCGA_MESO_exp_HiSeqV2  \
# sampleID
# TCGA-3H-AB3K-01  919d8bde-c3b7-4cd9-8463-938afdb89ad7
# TCGA-3H-AB3L-01  3baf5546-99d9-417b-97bb-e00dda7ebcdd
# TCGA-3H-AB3M-01  f0b52bcf-d7b4-4daa-82bb-e13e2d753be9
# TCGA-3H-AB3O-01  de645724-4408-4771-9814-cdeffec79758
# TCGA-3H-AB3S-01  34787f03-da7e-4f3e-b33f-73b1bf51fb74
#
#                  _GENOMIC_ID_TCGA_MESO_PDMRNAseqCNV  \
# sampleID
# TCGA-3H-AB3K-01                     TCGA-3H-AB3K-01
# TCGA-3H-AB3L-01                     TCGA-3H-AB3L-01
# TCGA-3H-AB3M-01                     TCGA-3H-AB3M-01
# TCGA-3H-AB3O-01                     TCGA-3H-AB3O-01
# TCGA-3H-AB3S-01                     TCGA-3H-AB3S-01
#
#                  _GENOMIC_ID_TCGA_MESO_gistic2thd  \
# sampleID
# TCGA-3H-AB3K-01      TCGA-3H-AB3K-01A-11D-A39Q-01
# TCGA-3H-AB3L-01      TCGA-3H-AB3L-01A-11D-A39Q-01
# TCGA-3H-AB3M-01      TCGA-3H-AB3M-01A-11D-A39Q-01
# TCGA-3H-AB3O-01      TCGA-3H-AB3O-01A-11D-A39Q-01
# TCGA-3H-AB3S-01      TCGA-3H-AB3S-01A-21D-A39Q-01
#
#                  _GENOMIC_ID_TCGA_MESO_hMethyl450
# sampleID
# TCGA-3H-AB3K-01      TCGA-3H-AB3K-01A-11D-A39S-05
# TCGA-3H-AB3L-01      TCGA-3H-AB3L-01A-11D-A39S-05
# TCGA-3H-AB3M-01      TCGA-3H-AB3M-01A-11D-A39S-05
# TCGA-3H-AB3O-01      TCGA-3H-AB3O-01A-11D-A39S-05
# TCGA-3H-AB3S-01      TCGA-3H-AB3S-01A-21D-A39S-05
#
# [5 rows x 96 columns]

# %%
gene_data.head()
# Out:
#            TCGA-SH-A7BC-01  TCGA-LK-A4NY-01  TCGA-3H-AB3L-01  TCGA-3U-A98F-01  \
# sample
# ARHGEF10L        -0.566692        -1.148192         0.200408        -2.360992
# HIF3A            -3.993126        -0.560126        -4.117426         2.860974
# RNF17            -0.124735        -0.531035        -0.531035        -0.055435
# RNF10             0.743328         0.631928         0.786128         0.011228
# RNF11             0.085322        -0.046578        -0.033878        -0.855678
#
#            TCGA-NQ-A638-01  TCGA-MQ-A6BS-01  TCGA-ZN-A9VV-01  TCGA-3H-AB3X-01  \
# sample
# ARHGEF10L        -0.098292        -0.386092        -1.352492         0.503108
# HIF3A            -1.254426        -1.119526         1.532374        -1.579526
# RNF17            -0.047735         0.034365        -0.531035        -0.531035
# RNF10             0.930628         0.492728         0.161328         0.271728
# RNF11            -0.103878         0.332522         0.252122        -0.106878
#
#            TCGA-3U-A98G-01  TCGA-TS-A7PB-01  ...  TCGA-YS-A95C-01  \
# sample                                       ...
# ARHGEF10L        -0.662192        -1.328692  ...        -0.833992
# HIF3A            -0.520126        -1.517626  ...        -3.770726
# RNF17            -0.531035        -0.531035  ...         0.620765
# RNF10            -0.002872         0.686128  ...         1.299528
# RNF11             0.498622         0.189322  ...        -0.638678
#
#            TCGA-MQ-A4LM-01  TCGA-3H-AB3T-01  TCGA-UT-A88D-01  TCGA-MQ-A4KX-01  \
# sample
# ARHGEF10L        -1.056392        -0.505092        -0.207492         0.072908
# HIF3A            -2.890926        -5.554726        -0.867826        -2.518126
# RNF17            -0.531035        -0.531035         1.192765        -0.531035
# RNF10            -0.037572         0.036928        -0.110272         1.019828
# RNF11            -0.081278        -0.100678         0.005822        -0.070778
#
#            TCGA-3U-A98I-01  TCGA-TS-A7OU-01  TCGA-LK-A4O6-01  TCGA-TS-A7P7-01  \
# sample
# ARHGEF10L        -0.578292         0.354308        -0.479092        -1.472692
# HIF3A            -1.904426        -3.805626         0.799274         3.710074
# RNF17            -0.531035        -0.531035        -0.531035        -0.531035
# RNF10             0.159728         1.244628         0.156228         0.730128
# RNF11             0.338022         0.530122        -0.568078         0.219122
#
#            TCGA-ZN-A9VW-01
# sample
# ARHGEF10L        -0.856492
# HIF3A            -0.225026
# RNF17            -0.531035
# RNF10             0.141428
# RNF11             0.302922
#
# [5 rows x 87 columns]

# %%
gene_fullname = 'Neurofibromatosis Type 2'
gene = 'NF2'
condition = 'age'
condition_col = 'days_to_birth'
trait = 'Mesothelioma'

# Get the feature dimension of clinical data, and the number of genes
col_offset = len(clinical_data.columns)
num_genes = len(gene_data)
print(f'The clinical dataset has {col_offset} features, and the gene dataset includes {num_genes} genes')
gene_data.T
# Out:
# The clinical dataset has 96 features, and the gene dataset includes 20530 genes
# sample           ARHGEF10L     HIF3A     RNF17     RNF10     RNF11    RNF13  \
# TCGA-SH-A7BC-01  -0.566692 -3.993126 -0.124735  0.743328  0.085322  0.30559
# TCGA-LK-A4NY-01  -1.148192 -0.560126 -0.531035  0.631928 -0.046578  0.23699
# TCGA-3H-AB3L-01   0.200408 -4.117426 -0.531035  0.786128 -0.033878  0.10959
# TCGA-3U-A98F-01  -2.360992  2.860974 -0.055435  0.011228 -0.855678 -0.54231
# TCGA-NQ-A638-01  -0.098292 -1.254426 -0.047735  0.930628 -0.103878  0.58769
# ...                    ...       ...       ...       ...       ...      ...
# TCGA-3U-A98I-01  -0.578292 -1.904426 -0.531035  0.159728  0.338022 -0.48511
# TCGA-TS-A7OU-01   0.354308 -3.805626 -0.531035  1.244628  0.530122  0.45969
# TCGA-LK-A4O6-01  -0.479092  0.799274 -0.531035  0.156228 -0.568078 -0.56301
# TCGA-TS-A7P7-01  -1.472692  3.710074 -0.531035  0.730128  0.219122 -0.37731
# TCGA-ZN-A9VW-01  -0.856492 -0.225026 -0.531035  0.141428  0.302922 -0.66011
#
# sample            GTF2IP1      REM1     MTVR2   RTN4RL2  ...     TULP2  \
# TCGA-SH-A7BC-01 -0.080794  0.308554  0.779001 -0.903372  ... -0.342578
# TCGA-LK-A4NY-01 -0.053894  0.635654 -0.423399 -0.076872  ... -0.149878
# TCGA-3H-AB3L-01 -0.456594 -0.717246 -0.423399 -0.440172  ... -0.748878
# TCGA-3U-A98F-01  0.055506  1.018154 -0.423399  0.800028  ...  0.083722
# TCGA-NQ-A638-01 -0.530994 -0.052446  0.059901  0.890928  ... -0.748878
# ...                   ...       ...       ...       ...  ...       ...
# TCGA-3U-A98I-01 -0.330194  1.377954 -0.423399  1.139328  ... -0.748878
# TCGA-TS-A7OU-01 -0.089494 -0.180246  0.246001 -3.123772  ... -0.748878
# TCGA-LK-A4O6-01  0.013106  2.456154 -0.423399  1.166128  ...  0.086522
# TCGA-TS-A7P7-01 -0.668394  2.277554  0.192201  3.104428  ... -0.133278
# TCGA-ZN-A9VW-01 -0.387394 -0.289446 -0.423399 -1.017672  ... -0.315778
#
# sample              NPY5R     GNGT2    GNGT1     TULP3      PTRF     BCL6B  \
# TCGA-SH-A7BC-01 -1.180817  1.348767 -1.28139  0.134123  3.063714 -0.633227
# TCGA-LK-A4NY-01  1.256083  0.057067  1.45441  0.154123  2.470714 -1.092527
# TCGA-3H-AB3L-01 -1.074117  0.139267 -0.39069  0.113323  2.440714  0.166873
# TCGA-3U-A98F-01 -0.025217  0.349767  2.34201  1.073923  2.052214 -0.200927
# TCGA-NQ-A638-01 -1.587117  1.167667  2.17121 -0.391177  3.177414 -1.125027
# ...                   ...       ...      ...       ...       ...       ...
# TCGA-3U-A98I-01 -1.587117  0.717367 -1.28139  0.493123  2.570714  1.599373
# TCGA-TS-A7OU-01  1.318683  2.146167 -0.61199 -0.536977  1.850314 -0.951527
# TCGA-LK-A4O6-01 -1.587117  0.855267 -1.28139  0.235023  2.880314  0.721473
# TCGA-TS-A7P7-01 -0.210517 -1.224433 -1.28139  0.834123  2.526814  1.862473
# TCGA-ZN-A9VW-01 -0.551217  0.904467 -1.28139  0.455123  2.891514  0.223173
#
# sample              GSTK1      SELP      SELS
# TCGA-SH-A7BC-01  0.519305  1.216667  0.085688
# TCGA-LK-A4NY-01  0.420705  2.621967  0.272188
# TCGA-3H-AB3L-01  0.070905  0.942767  1.119988
# TCGA-3U-A98F-01 -0.438495  0.941467 -1.184112
# TCGA-NQ-A638-01  0.260005  0.033967  0.443288
# ...                   ...       ...       ...
# TCGA-3U-A98I-01 -0.354695  2.327567  0.206688
# TCGA-TS-A7OU-01  0.629005 -0.204833  0.730288
# TCGA-LK-A4O6-01  0.526505  2.945267  0.044288
# TCGA-TS-A7P7-01 -0.112595  1.602767 -0.410312
# TCGA-ZN-A9VW-01 -0.243395  0.003267 -0.212412
#
# [87 rows x 20530 columns]

# %%
merged_data = clinical_data.join(gene_data.T)

merged_data.head()
# Out:
#                     _INTEGRATION      _PATIENT                   _cohort  \
# sampleID
# TCGA-3H-AB3K-01  TCGA-3H-AB3K-01  TCGA-3H-AB3K  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3L-01  TCGA-3H-AB3L-01  TCGA-3H-AB3L  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3M-01  TCGA-3H-AB3M-01  TCGA-3H-AB3M  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3O-01  TCGA-3H-AB3O-01  TCGA-3H-AB3O  TCGA Mesothelioma (MESO)
# TCGA-3H-AB3S-01  TCGA-3H-AB3S-01  TCGA-3H-AB3S  TCGA Mesothelioma (MESO)
#
#                 _primary_disease            _primary_site  \
# sampleID
# TCGA-3H-AB3K-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3L-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3M-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3O-01     mesothelioma  Lining of body cavities
# TCGA-3H-AB3S-01     mesothelioma  Lining of body cavities
#
#                 additional_pharmaceutical_therapy  \
# sampleID
# TCGA-3H-AB3K-01                               NaN
# TCGA-3H-AB3L-01                               NaN
# TCGA-3H-AB3M-01                               NaN
# TCGA-3H-AB3O-01                               NaN
# TCGA-3H-AB3S-01                               NaN
#
#                 additional_radiation_therapy  \
# sampleID
# TCGA-3H-AB3K-01                          NaN
# TCGA-3H-AB3L-01                          NaN
# TCGA-3H-AB3M-01                          NaN
# TCGA-3H-AB3O-01                          NaN
# TCGA-3H-AB3S-01                          NaN
#
#                  age_at_initial_pathologic_diagnosis  asbestos_exposure_age  \
# sampleID
# TCGA-3H-AB3K-01                                   64                    NaN
# TCGA-3H-AB3L-01                                   60                    NaN
# TCGA-3H-AB3M-01                                   53                    NaN
# TCGA-3H-AB3O-01                                   58                   25.0
# TCGA-3H-AB3S-01                                   69                    NaN
#
#                  asbestos_exposure_age_last  ...     TULP2     NPY5R  \
# sampleID                                     ...
# TCGA-3H-AB3K-01                         NaN  ... -0.061978 -0.900217
# TCGA-3H-AB3L-01                         NaN  ... -0.748878 -1.074117
# TCGA-3H-AB3M-01                         NaN  ...  0.062822 -1.124917
# TCGA-3H-AB3O-01                        31.0  ...  1.031722  0.384783
# TCGA-3H-AB3S-01                         NaN  ... -0.748878 -1.587117
#
#                     GNGT2    GNGT1     TULP3      PTRF     BCL6B     GSTK1  \
# sampleID
# TCGA-3H-AB3K-01  0.803567 -1.28139 -0.551677  2.729314 -2.035927  0.175405
# TCGA-3H-AB3L-01  0.139267 -0.39069  0.113323  2.440714  0.166873  0.070905
# TCGA-3H-AB3M-01  0.242467 -0.46969  0.307823  2.412214 -1.703127 -0.213695
# TCGA-3H-AB3O-01  3.061667 -1.28139 -0.580077  1.625214  0.947073  1.408105
# TCGA-3H-AB3S-01 -0.441533 -1.28139  0.417023  2.804214 -0.154627 -0.004295
#
#                      SELP      SELS
# sampleID
# TCGA-3H-AB3K-01  0.164067  0.896588
# TCGA-3H-AB3L-01  0.942767  1.119988
# TCGA-3H-AB3M-01  1.932667  0.740488
# TCGA-3H-AB3O-01  2.816367  0.836088
# TCGA-3H-AB3S-01 -0.111033  0.586488
#
# [5 rows x 20626 columns]

# %%
input_cols = [condition_col] + merged_data.columns[col_offset: col_offset + num_genes].tolist()
merged_data = merged_data[input_cols]


threshold_rows = 0.22 * len(merged_data)
rows_after_any = len(merged_data.dropna(how='any'))

if rows_after_any >= threshold_rows:
    merged_data = merged_data.dropna(how='any')
else:
    merged_data = merged_data.dropna(how='all')
    merged_data = merged_data.fillna(0)

merged_data.head()
# Out:
#                  days_to_birth  ARHGEF10L     HIF3A     RNF17     RNF10  \
# sampleID
# TCGA-3H-AB3K-01         -23591   0.160908 -3.157426 -0.531035  0.483128
# TCGA-3H-AB3L-01         -21972   0.200408 -4.117426 -0.531035  0.786128
# TCGA-3H-AB3M-01         -19503  -1.009592 -2.663326 -0.068835  0.828928
# TCGA-3H-AB3O-01         -21423  -0.147492 -2.266526 -0.531035  0.274528
# TCGA-3H-AB3S-01         -25471   0.282008 -2.042126 -0.531035  0.825228
#
#                     RNF11    RNF13   GTF2IP1      REM1     MTVR2  ...  \
# sampleID                                                          ...
# TCGA-3H-AB3K-01 -0.152778  0.65969  0.001606  0.095754 -0.423399  ...
# TCGA-3H-AB3L-01 -0.033878  0.10959 -0.456594 -0.717246 -0.423399  ...
# TCGA-3H-AB3M-01 -0.737678  0.77649 -0.002594 -0.552846  0.388301  ...
# TCGA-3H-AB3O-01 -0.311878  0.31179 -1.012494  2.159654  0.149201  ...
# TCGA-3H-AB3S-01 -0.210878  0.07039 -0.070994  0.310754 -0.423399  ...
#
#                     TULP2     NPY5R     GNGT2    GNGT1     TULP3      PTRF  \
# sampleID
# TCGA-3H-AB3K-01 -0.061978 -0.900217  0.803567 -1.28139 -0.551677  2.729314
# TCGA-3H-AB3L-01 -0.748878 -1.074117  0.139267 -0.39069  0.113323  2.440714
# TCGA-3H-AB3M-01  0.062822 -1.124917  0.242467 -0.46969  0.307823  2.412214
# TCGA-3H-AB3O-01  1.031722  0.384783  3.061667 -1.28139 -0.580077  1.625214
# TCGA-3H-AB3S-01 -0.748878 -1.587117 -0.441533 -1.28139  0.417023  2.804214
#
#                     BCL6B     GSTK1      SELP      SELS
# sampleID
# TCGA-3H-AB3K-01 -2.035927  0.175405  0.164067  0.896588
# TCGA-3H-AB3L-01  0.166873  0.070905  0.942767  1.119988
# TCGA-3H-AB3M-01 -1.703127 -0.213695  1.932667  0.740488
# TCGA-3H-AB3O-01  0.947073  1.408105  2.816367  0.836088
# TCGA-3H-AB3S-01 -0.154627 -0.004295 -0.111033  0.586488
#
# [5 rows x 20531 columns]

# %% [markdown]
# # 2. Preliminary analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plot_numeric_distribution(df, column):
    plt.figure(figsize=(10, 15))
    sns.histplot(df[column], kde=True, bins=30)
    plt.title(f'Distribution of {column.capitalize()}')
    plt.xlabel('')
    plt.ylabel('Frequency')
    plt.show()

def plot_categorical_distribution(df, column):
    plt.figure(figsize=(10, 6))
    sns.countplot(y=column, data=df, order=df[column].value_counts().index)
    plt.title(f'Distribution of {column.capitalize()}')
    plt.xlabel('Frequency')
    plt.ylabel('')
    plt.show()

def analyze_distributions(df, numerical_columns, categorical_columns):
    for col in numerical_columns:
        plot_numeric_distribution(df, col)

    for col in categorical_columns:
        plot_categorical_distribution(df, col)

# Sample usage:
analyze_distributions(merged_data, numerical_columns=[condition_col,], categorical_columns=[trait])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mesothelioma'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\temp\temp\ipykernel_5040\4278609877.py in <module>
#      26
#      27 # Sample usage:
# ---> 28 analyze_distributions(merged_data, numerical_columns=[condition_col,], categorical_columns=[trait])
#
# d:\temp\temp\ipykernel_5040\4278609877.py in analyze_distributions(df, numerical_columns, categorical_columns)
#      23
#      24     for col in categorical_columns:
# ---> 25         plot_categorical_distribution(df, col)
#      26
#      27 # Sample usage:
#
# d:\temp\temp\ipykernel_5040\4278609877.py in plot_categorical_distribution(df, column)
#      12 def plot_categorical_distribution(df, column):
#      13     plt.figure(figsize=(10, 6))
# ---> 14     sns.countplot(y=column, data=df, order=df[column].value_counts().index)
#      15     plt.title(f'Distribution of {column.capitalize()}')
#      16     plt.xlabel('Frequency')
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Mesothelioma'

# %%
sns.scatterplot(data=merged_data, x='BRCA1', y='BRCA2')
plt.show()
sns.scatterplot(data=merged_data, x='BRCA2', y=condition_col)
plt.show()

# %% [markdown]
# # 3. Do regression & Cross Validation

# %%
merged_data[condition_col] = (- merged_data[condition_col] / 365.25).astype(int)
merged_data = merged_data.rename(columns={condition_col: condition})
input_cols = merged_data.columns.tolist()

merged_data.head()
# Out:
#                  age  ARHGEF10L     HIF3A     RNF17     RNF10     RNF11  \
# sampleID
# TCGA-3H-AB3K-01   64   0.160908 -3.157426 -0.531035  0.483128 -0.152778
# TCGA-3H-AB3L-01   60   0.200408 -4.117426 -0.531035  0.786128 -0.033878
# TCGA-3H-AB3M-01   53  -1.009592 -2.663326 -0.068835  0.828928 -0.737678
# TCGA-3H-AB3O-01   58  -0.147492 -2.266526 -0.531035  0.274528 -0.311878
# TCGA-3H-AB3S-01   69   0.282008 -2.042126 -0.531035  0.825228 -0.210878
#
#                    RNF13   GTF2IP1      REM1     MTVR2  ...     TULP2  \
# sampleID                                                ...
# TCGA-3H-AB3K-01  0.65969  0.001606  0.095754 -0.423399  ... -0.061978
# TCGA-3H-AB3L-01  0.10959 -0.456594 -0.717246 -0.423399  ... -0.748878
# TCGA-3H-AB3M-01  0.77649 -0.002594 -0.552846  0.388301  ...  0.062822
# TCGA-3H-AB3O-01  0.31179 -1.012494  2.159654  0.149201  ...  1.031722
# TCGA-3H-AB3S-01  0.07039 -0.070994  0.310754 -0.423399  ... -0.748878
#
#                     NPY5R     GNGT2    GNGT1     TULP3      PTRF     BCL6B  \
# sampleID
# TCGA-3H-AB3K-01 -0.900217  0.803567 -1.28139 -0.551677  2.729314 -2.035927
# TCGA-3H-AB3L-01 -1.074117  0.139267 -0.39069  0.113323  2.440714  0.166873
# TCGA-3H-AB3M-01 -1.124917  0.242467 -0.46969  0.307823  2.412214 -1.703127
# TCGA-3H-AB3O-01  0.384783  3.061667 -1.28139 -0.580077  1.625214  0.947073
# TCGA-3H-AB3S-01 -1.587117 -0.441533 -1.28139  0.417023  2.804214 -0.154627
#
#                     GSTK1      SELP      SELS
# sampleID
# TCGA-3H-AB3K-01  0.175405  0.164067  0.896588
# TCGA-3H-AB3L-01  0.070905  0.942767  1.119988
# TCGA-3H-AB3M-01 -0.213695  1.932667  0.740488
# TCGA-3H-AB3O-01  1.408105  2.816367  0.836088
# TCGA-3H-AB3S-01 -0.004295 -0.111033  0.586488
#
# [5 rows x 20531 columns]

# %%
import pandas as pd
from sparse_lmm import VariableSelection

# Select relevant columns and convert to numpy array
data_array = merged_data.values

# Normalize data
X = data_array
mean = np.mean(X, axis=0)
std = np.std(X, axis=0)
zero_std_columns = np.where(std == 0)[0]
X = (X - mean) / std
X[:, zero_std_columns] = 0

y = merged_data[trait].values

# Implementing k-fold cross-validation
def cross_validation(X, y, k=5):
    # Shuffle data
    indices = np.arange(X.shape[0])
    np.random.shuffle(indices)
    X_shuffled = X[indices]
    y_shuffled = y[indices]

    fold_size = len(X) // k
    accuracies = []

    for i in range(k):
        # Split data into train and test based on the current fold
        test_indices = indices[i*fold_size : (i+1)*fold_size]
        train_indices = np.setdiff1d(indices, test_indices)

        X_train, X_test = X_shuffled[train_indices], X_shuffled[test_indices]
        y_train, y_test = y_shuffled[train_indices], y_shuffled[test_indices]

        # Use the precision_lasso package for regression
        var_select = VariableSelection()
        var_select.fit(X_train, y_train)
        predictions = var_select.predict(X_test)

        binary_predictions = (predictions > 0.5).astype(int)

        accuracy = np.mean(binary_predictions == y_test)
        accuracies.append(accuracy)

    return np.mean(accuracies)

print(cross_validation(data_array, y))
# Out:
# d:\temp\temp\ipykernel_5040\1545064521.py:12: RuntimeWarning: invalid value encountered in true_divide
#   X = (X - mean) / std
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mesothelioma'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\temp\temp\ipykernel_5040\1545064521.py in <module>
#      13 X[:, zero_std_columns] = 0
#      14
# ---> 15 y = merged_data[trait].values
#      16
#      17 # Implementing k-fold cross-validation
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Mesothelioma'

# %%
gene_result = []
condition_result = []

# Extract information related to the regressors
for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values):
    if gene in var.lower():
        gene_result.append((var, coef, np.exp(-nlogp)))
    if condition == var.lower():
        condition_result.append((var, coef, np.exp(-nlogp)))

regression_report = "Regression Results:\n\n"
regression_report += f"For {gene}:\n"
for variable_name, coefficient, p_value in gene_result:
    regression_report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"

regression_report += f"\nFor {condition}:\n"
for variable_name, coefficient, p_value in condition_result:
    regression_report += f"{variable_name}: Coefficient = {coefficient}, p-value = {p_value}\n"

print(regression_report)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\temp\temp\ipykernel_5040\3663073413.py in <module>
#       3
#       4 # Extract information related to the regressors
# ----> 5 for var, coef, nlogp in zip(input_cols, coefficients, nlog_p_values):
#       6     if gene in var.lower():
#       7         gene_result.append((var, coef, np.exp(-nlogp)))
#
# NameError: name 'coefficients' is not defined

# %% [markdown]
# # 4.Discussion

# %% [raw]
# Variable:PTEN Conclusion:NF2 gene is not rejected: There is insufficient evidence to conclude a significant association between the expression of the BRCA1 gene and Colon Cancer when considering the influence of age.
#
# Variable: PTEN0 Conclusion: NF2 geneis not rejected: There is insufficient evidence to conclude a significant association between the expression of the BRCA2 gene and Colon Cancer when considering the influence of age.
